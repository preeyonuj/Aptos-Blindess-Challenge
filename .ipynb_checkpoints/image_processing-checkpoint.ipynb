# %% [markdown]
# The first part of this notebook will focus Neuron Engineer's work. (https://www.kaggle.com/ratthachat/aptos-eye-preprocessing-in-diabetic-retinopathy) He made a perfect notebook on Kaggle about pre-processing on the retina images.

# %%
# import block
import numpy as np
import pandas as pd
import cv2
import random
import glob
import matplotlib.pyplot as plt

SEED=42

# %%
# train dataframe
train_data_df = pd.read_csv("D:\\Data_Science\\Datasets\\Aptos-Blindness-Challenge\\data\\train.csv")
train_data_df.head()
# Out:
#         id_code  diagnosis
# 0  000c1434d8d7          2
# 1  001639a390f0          4
# 2  0024cdab0c1e          1
# 3  002c21358ce6          0
# 4  005b95c28852          0

# %%
# Take 5 images from each class
# I already modified the train data structure so that they are separated by class. 
random_files_list = []
class_list = [0,1,2,3,4]
data_path = "D:\\Data_Science\\Datasets\\Aptos-Blindness-Challenge\\data\\train\\separated\\train\\"
for cls in class_list:
    random_files_list.append(random.sample(glob.glob(data_path+str(cls)+"\\*"),5))
random_files_list = [j for i in random_files_list for j in i]

# %%
# Visualizing the 5 images
row, ind = 0, 0 
f, axarr = plt.subplots(5,5, figsize=(15,15))
for image in random_files_list:
    img = cv2.imread(image,3)
    axarr[row,ind].imshow(img)
    ind += 1
    if ind == 5:
        ind = 0
        row += 1 
plt.show()
